# %% [markdown]
# # Convolutional neural networks for artistic style transfer
#
# * This iPython notebook is an implementation of a popular paper ([Gatys et al., 2015](https://arxiv.org/abs/1508.06576)) that demonstrates how to use neural networks to transfer artistic style from one image onto another. It is meant to go along with a [related blog post](https://harishnarayanan.org/writing/artistic-style-transfer/) that provides more context, and explains a lot of the theory behind the steps that follow.
# * There will be a companion blog post and project coming soon in the future that implements a much faster version of this algorithm ([Johnson et al., 2016](https://arxiv.org/abs/1603.08155)) and wraps it in a webapp, a la [Prisma](https://prisma-ai.com).

# %%
import time
from PIL import Image
import numpy as np
from keras import backend
from keras.models import Model
from keras.applications.vgg16 import VGG16
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import h5py

# %% [markdown]
# ## Load and preprocess the content and style images
#
# Our first task is to load the content and style images. Note that the content image we're working with is not particularly high quality, but the output we'll arrive at the end of this process still looks really good.

# %%
height = 512
width = 512

content_image_path = 'images/tubingen.jpg'
content_image = Image.open(content_image_path)
content_image = content_image.resize((width, height))
content_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x269FD8684A8>

# %%
style_image_path = 'images/2.jpg'
style_image = Image.open(style_image_path)
style_image = style_image.resize((width, height))
style_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x269FD868BA8>

# %% [markdown]
# Then, we convert these images into a form suitable for numerical processing. In particular, we add another dimension (beyond the classic height x width x 3 dimensions) so that we can later concatenate the representations of these two images into a common data structure.

# %%
content_array = np.asarray(content_image, dtype='float32')
content_array = np.expand_dims(content_array, axis=0)
print(content_array.shape)
style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)
print(style_array.shape)
# Out:
# (1, 512, 512, 3)
# (1, 512, 512, 3)

# %% [markdown]
# Before we proceed much further, we need to massage this input data to match what was done in [Simonyan and Zisserman (2015)](https://arxiv.org/abs/1409.1556), the paper that introduces the *VGG Network* model that we're going to use shortly.
#
# For this, we need to perform two transformations:
#
# 1. Subtract the mean RGB value (computed previously on the [ImageNet training set](http://image-net.org) and easily obtainable from Google searches) from each pixel.
# 2. Flip the ordering of the multi-dimensional array from *RGB* to *BGR* (the ordering used in the paper).

# %%
content_array[:, :, :, 0] -= 103.939
content_array[:, :, :, 1] -= 116.779
content_array[:, :, :, 2] -= 123.68
content_array = content_array[:, :, :, ::-1]
style_array[:, :, :, 0] -= 103.939
style_array[:, :, :, 1] -= 116.779
style_array[:, :, :, 2] -= 123.68
style_array = style_array[:, :, :, ::-1]

# %% [markdown]
# Now we're ready to use these arrays to define variables in Keras' backend (the TensorFlow graph). We also introduce a placeholder variable to store the *combination* image that retains the content of the content image while incorporating the style of the style image.

# %%
content_image = backend.variable(content_array)
style_image = backend.variable(style_array)
combination_image = backend.placeholder((1, height, width, 3))

# %% [markdown]
# Finally, we concatenate all this image data into a single tensor that's suitable for processing by Keras' VGG16 model.

# %%
input_tensor = backend.concatenate([content_image,
                                    style_image,
                                    combination_image], axis=0)

# %% [markdown]
# ## Reuse a model pre-trained for image classification to define loss functions
#
# The core idea introduced by [Gatys et al. (2015)](https://arxiv.org/abs/1508.06576) is that convolutional neural networks (CNNs) pre-trained for image classification already know how to encode perceptual and semantic information about images. We're going to follow their idea, and use the *feature spaces* provided by one such model to independently work with content and style of images.
#
# The original paper uses the 19 layer VGG network model from [Simonyan and Zisserman (2015)](https://arxiv.org/abs/1409.1556), but we're going to instead follow [Johnson et al. (2016)](https://arxiv.org/abs/1603.08155) and use the 16 layer model (VGG16). There is no noticeable qualitative difference in making this choice, and we gain a tiny bit in speed.
#
# Also, since we're not interested in the classification problem, we don't need the fully connected layers or the final softmax classifier. We only need the part of the model marked in green in the table below.
#
# It is trivial for us to get access to this truncated model because Keras comes with a set of pretrained models, including the VGG16 model we're interested in. Note that by setting `include_top=False` in the code below, we don't include any of the fully connected layers.

# %%
model = VGG16(input_tensor=input_tensor, weights='imagenet',include_top=False)

# %% [markdown]
# As is clear from the table above, the model we're working with has a lot of layers. Keras has its own names for these layers. Let's make a list of these names so that we can easily refer to individual layers later.

# %%
layers = dict([(layer.name, layer.output) for layer in model.layers])
layers
# Out:
# {'block1_conv1': <tf.Tensor 'block1_conv1_1/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2_1/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool_1/MaxPool:0' shape=(3, 256, 256, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1_1/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2_1/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool_1/MaxPool:0' shape=(3, 128, 128, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3_1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool_1/MaxPool:0' shape=(3, 64, 64, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3_1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool_1/MaxPool:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3_1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool_1/MaxPool:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'input_2': <tf.Tensor 'concat_1:0' shape=(3, 512, 512, 3) dtype=float32>}

# %% [markdown]
# If you stare at the list above, you'll convince yourself that we covered all items we wanted in the table (the cells marked in green). Notice also that because we provided Keras with a concrete input tensor, the various TensorFlow tensors get well-defined shapes.
#
# ---
#
# The crux of the paper we're trying to reproduce is that the [style transfer problem can be posed as an optimisation problem](https://harishnarayanan.org/writing/artistic-style-transfer/), where the loss function we want to minimise can be decomposed into three distinct parts: the *content loss*, the *style loss* and the *total variation loss*.
#
# The relative importance of these terms are determined by a set of scalar weights. These are  arbitrary, but the following set have been chosen after quite a bit of experimentation to find a set that generates output that's aesthetically pleasing to me.

# %%
content_weight = 0.025
style_weight = 5.0
total_variation_weight = 1.0

# %% [markdown]
# We'll now use the feature spaces provided by specific layers of our model to define these three loss functions. We begin by initialising the total loss to 0 and adding to it in stages.

# %%
loss = backend.variable(0.)

# %% [markdown]
# ### The content loss
#
# For the content loss, we follow Johnson et al. (2016) and draw the content feature from `block2_conv2`, because the original choice in Gatys et al. (2015) (`block4_conv2`) loses too much structural detail. And at least for faces, I find it more aesthetically pleasing to closely retain the structure of the original content image.
#
# This variation across layers is shown for a couple of examples in the images below (just mentally replace `reluX_Y` with our Keras notation `blockX_convY`).
#
#
# The content loss is the (scaled, squared) Euclidean distance between feature representations of the content and combination images.

# %%
def content_loss(content, combination):
    return backend.sum(backend.square(combination - content))

layer_features = layers['block2_conv2']
content_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]

loss += content_weight * content_loss(content_image_features,
                                      combination_features)

# %% [markdown]
# ### The style loss
#
# This is where things start to get a bit intricate.
#
# For the style loss, we first define something called a *Gram matrix*. The terms of this matrix are proportional to the covariances of corresponding sets of features, and thus captures information about which features tend to activate together. By only capturing these aggregate statistics across the image, they are blind to the specific arrangement of objects inside the image. This is what allows them to capture information about style independent of content. (This is not trivial at all, and I refer you to [a paper that attempts to explain the idea](https://arxiv.org/abs/1606.01286).)
#
# The Gram matrix can be computed efficiently by reshaping the feature spaces suitably and taking an outer product.

# %%
def gram_matrix(x):
    features = backend.batch_flatten(backend.permute_dimensions(x, (2, 0, 1)))
    gram = backend.dot(features, backend.transpose(features))
    return gram

# %% [markdown]
# The style loss is then the (scaled, squared) Frobenius norm of the difference between the Gram matrices of the style and combination images.
#
# Again, in the following code, I've chosen to go with the style features from layers defined in Johnson et al. (2016) rather than Gatys et al. (2015) because I find the end results more aesthetically pleasing. I encourage you to experiment with these choices to see varying results.

# %% [markdown]
# def style_loss(style, combination):
#     S = gram_matrix(style)
#     C = gram_matrix(combination)
#     channels = 3
#     size = height * width
#     return backend.sum(backend.square(S - C)) / (4. * (channels ** 2) * (size ** 2))
#
# feature_layers = ['block1_conv2', 'block2_conv2',
#                   'block3_conv3', 'block4_conv3',
#                   'block5_conv3']
# for layer_name in feature_layers:
#     layer_features = layers[layer_name]
#     style_features = layer_features[1, :, :, :]
#     combination_features = layer_features[2, :, :, :]
#     sl = style_loss(style_features, combination_features)
#     loss += (style_weight / len(feature_layers)) * sl
# #print(loss)

# %% [markdown]
# ### The total variation loss
#
# Now we're back on simpler ground.
#
# If you were to solve the optimisation problem with only the two loss terms we've introduced so far (style and content), you'll find that the output is quite noisy. We thus add another term, called the [total variation loss](http://arxiv.org/abs/1412.0035) (a regularisation term) that encourages spatial smoothness.
#
# You can experiment with reducing the `total_variation_weight` and play with the noise-level of the generated image.

# %%
def total_variation_loss(x):
    a = backend.square(x[:, :height-1, :width-1, :] - x[:, 1:, :width-1, :])
    b = backend.square(x[:, :height-1, :width-1, :] - x[:, :height-1, 1:, :])
    return backend.sum(backend.pow(a + b, 1.25))

loss += total_variation_weight * total_variation_loss(combination_image)

# %% [markdown]
# ## Define needed gradients and solve the optimisation problem
#
# [The goal of this journey](https://harishnarayanan.org/writing/artistic-style-transfer/) was to setup an optimisation problem that aims to solve for a *combination image* that contains the content of the content image, while having the style of the style image. Now that we have our input images massaged and our loss function calculators in place, all we have left to do is define gradients of the total loss relative to the combination image, and use these gradients to iteratively improve upon our combination image to minimise the loss.
#
# We start by defining the gradients.

# %%
grads = backend.gradients(loss, combination_image)

# %% [markdown]
# We then introduce an `Evaluator` class that computes loss and gradients in one pass while retrieving them via two separate functions, `loss` and `grads`. This is done because `scipy.optimize` requires separate functions for loss and gradients, but computing them separately would be inefficient.

# %%
outputs = [loss]
outputs += grads
f_outputs = backend.function([combination_image], outputs)

def eval_loss_and_grads(x):
    x = x.reshape((1, height, width, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    grad_values = outs[1].flatten().astype('float64')
    return loss_value, grad_values

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %% [markdown]
# Now we're finally ready to solve our optimisation problem. This combination image begins its life as a random collection of (valid) pixels, and we use the [L-BFGS](https://en.wikipedia.org/wiki/Limited-memory_BFGS) algorithm (a quasi-Newton algorithm that's significantly quicker to converge than standard gradient descent) to iteratively improve upon it.
#
# We stop after 10 iterations because the output looks good to me and the loss stops reducing significantly.

# %%
x = np.random.uniform(0, 255, (1, height, width, 3)) - 128.

iterations = 1000

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time -  start_time))
# Out:
# Start of iteration 0
# Current loss value: 7257321000.0
# Iteration 0 completed in 144s
# Start of iteration 1
# Current loss value: 5513576400.0
# Iteration 1 completed in 141s
# Start of iteration 2
# Current loss value: 4930187300.0
# Iteration 2 completed in 142s
# Start of iteration 3
# Current loss value: 4650680300.0
# Iteration 3 completed in 141s
# Start of iteration 4
# Current loss value: 4531343000.0
# Iteration 4 completed in 142s
# Start of iteration 5
# Current loss value: 4465110000.0
# Iteration 5 completed in 141s
# Start of iteration 6
# Current loss value: 4430674000.0
# Iteration 6 completed in 141s
# Start of iteration 7
# Current loss value: 4408287000.0
# Iteration 7 completed in 129s
# Start of iteration 8
# Current loss value: 4390896600.0
# Iteration 8 completed in 141s
# Start of iteration 9
# Current loss value: 4377285600.0
# Iteration 9 completed in 141s
# Start of iteration 10
# Current loss value: 4366251000.0
# Iteration 10 completed in 141s
# Start of iteration 11
# Current loss value: 4357556700.0
# Iteration 11 completed in 142s
# Start of iteration 12
# Current loss value: 4350684700.0
# Iteration 12 completed in 142s
# Start of iteration 13
# Current loss value: 4345212000.0
# Iteration 13 completed in 140s
# Start of iteration 14
# Current loss value: 4340829700.0
# Iteration 14 completed in 114s
# Start of iteration 15
# Current loss value: 4337357300.0
# Iteration 15 completed in 114s
# Start of iteration 16
# Current loss value: 4334496000.0
# Iteration 16 completed in 114s
# Start of iteration 17
# Current loss value: 4332225500.0
# Iteration 17 completed in 114s
# Start of iteration 18
# Current loss value: 4330281000.0
# Iteration 18 completed in 114s
# Start of iteration 19
# Current loss value: 4328536600.0
# Iteration 19 completed in 114s
# Start of iteration 20
# Current loss value: 4327017500.0
# Iteration 20 completed in 114s
# Start of iteration 21
# Current loss value: 4325711400.0
# Iteration 21 completed in 114s
# Start of iteration 22
# Current loss value: 4324641000.0
# Iteration 22 completed in 114s
# Start of iteration 23
# Current loss value: 4323697700.0
# Iteration 23 completed in 114s
# Start of iteration 24
# Current loss value: 4322914300.0
# Iteration 24 completed in 114s
# Start of iteration 25
# Current loss value: 4322292700.0
# Iteration 25 completed in 114s
# Start of iteration 26
# Current loss value: 4321754000.0
# Iteration 26 completed in 114s
# Start of iteration 27
# Current loss value: 4321292000.0
# Iteration 27 completed in 114s
# Start of iteration 28
# Current loss value: 4320893400.0
# Iteration 28 completed in 114s
# Start of iteration 29
# Current loss value: 4320545000.0
# Iteration 29 completed in 114s
# Start of iteration 30
# Current loss value: 4320234500.0
# Iteration 30 completed in 114s
# Start of iteration 31
# Current loss value: 4319954000.0
# Iteration 31 completed in 114s
# Start of iteration 32
# Current loss value: 4319701500.0
# Iteration 32 completed in 114s
# Start of iteration 33
# Current loss value: 4319478000.0
# Iteration 33 completed in 114s
# Start of iteration 34
# Current loss value: 4319266000.0
# Iteration 34 completed in 114s
# Start of iteration 35
# Current loss value: 4319062500.0
# Iteration 35 completed in 114s
# Start of iteration 36
# Current loss value: 4318875600.0
# Iteration 36 completed in 114s
# Start of iteration 37
# Current loss value: 4318704600.0
# Iteration 37 completed in 114s
# Start of iteration 38
# Current loss value: 4318551600.0
# Iteration 38 completed in 114s
# Start of iteration 39
# Current loss value: 4318413300.0
# Iteration 39 completed in 114s
# Start of iteration 40
# Current loss value: 4318286000.0
# Iteration 40 completed in 116s
# Start of iteration 41
# Current loss value: 4318168000.0
# Iteration 41 completed in 116s
# Start of iteration 42
# Current loss value: 4318055000.0
# Iteration 42 completed in 115s
# Start of iteration 43
# Current loss value: 4317950000.0
# Iteration 43 completed in 115s
# Start of iteration 44
# Current loss value: 4317853700.0
# Iteration 44 completed in 114s
# Start of iteration 45
# Current loss value: 4317763600.0
# Iteration 45 completed in 113s
# Start of iteration 46
# Current loss value: 4317675500.0
# Iteration 46 completed in 113s
# Start of iteration 47
# Current loss value: 4317591600.0
# Iteration 47 completed in 113s
# Start of iteration 48
# Current loss value: 4317508600.0
# Iteration 48 completed in 114s
# Start of iteration 49
# Current loss value: 4317435400.0
# Iteration 49 completed in 113s
# Start of iteration 50
# Current loss value: 4317363000.0
# Iteration 50 completed in 114s
# Start of iteration 51
# Current loss value: 4317290500.0
# Iteration 51 completed in 113s
# Start of iteration 52
# Current loss value: 4317239300.0
# Iteration 52 completed in 118s
# Start of iteration 53
# Current loss value: 4317228000.0
# Iteration 53 completed in 155s
# Start of iteration 54
# Current loss value: 4317228000.0
# Iteration 54 completed in 75s
# Start of iteration 55
# Current loss value: 4317228000.0
# Iteration 55 completed in 85s
# Start of iteration 56
# Current loss value: 4317228000.0
# Iteration 56 completed in 85s
# Start of iteration 57
# Current loss value: 4317228000.0
# Iteration 57 completed in 96s
# Start of iteration 58
# Current loss value: 4317228000.0
# Iteration 58 completed in 106s
# Start of iteration 59
# Current loss value: 4317228000.0
# Iteration 59 completed in 85s
# Start of iteration 60
# Current loss value: 4317228000.0
# Iteration 60 completed in 75s
# Start of iteration 61
# Current loss value: 4317228000.0
# Iteration 61 completed in 96s
# Start of iteration 62
# Current loss value: 4317228000.0
# Iteration 62 completed in 85s
# Start of iteration 63
# Current loss value: 4317228000.0
# Iteration 63 completed in 112s
# Start of iteration 64
# Current loss value: 4317228000.0
# Iteration 64 completed in 96s
# Start of iteration 65
# Current loss value: 4317228000.0
# Iteration 65 completed in 85s
# Start of iteration 66
# Current loss value: 4317228000.0
# Iteration 66 completed in 85s
# Start of iteration 67
# Current loss value: 4317228000.0
# Iteration 67 completed in 74s
# Start of iteration 68
# Current loss value: 4317228000.0
# Iteration 68 completed in 96s
# Start of iteration 69
# Current loss value: 4317228000.0
# Iteration 69 completed in 96s
# Start of iteration 70
# Current loss value: 4317228000.0
# Iteration 70 completed in 85s
# Start of iteration 71
# Current loss value: 4317228000.0
# Iteration 71 completed in 80s
# Start of iteration 72
# Current loss value: 4317228000.0
# Iteration 72 completed in 86s
# Start of iteration 73
# Current loss value: 4317228000.0
# Iteration 73 completed in 74s
# Start of iteration 74
# Current loss value: 4317228000.0
# Iteration 74 completed in 96s
# Start of iteration 75
# Current loss value: 4317228000.0
# Iteration 75 completed in 80s
# Start of iteration 76
# Current loss value: 4317228000.0
# Iteration 76 completed in 96s
# Start of iteration 77
# Current loss value: 4317228000.0
# Iteration 77 completed in 75s
# Start of iteration 78
# Current loss value: 4317228000.0
# Iteration 78 completed in 85s
# Start of iteration 79
# Current loss value: 4317228000.0
# Iteration 79 completed in 75s
# Start of iteration 80
# Current loss value: 4317228000.0
# Iteration 80 completed in 96s
# Start of iteration 81
# Current loss value: 4317228000.0
# Iteration 81 completed in 96s
# Start of iteration 82
# Current loss value: 4317228000.0
# Iteration 82 completed in 90s
# Start of iteration 83
# Current loss value: 4317228000.0
# Iteration 83 completed in 75s
# Start of iteration 84
# Current loss value: 4317228000.0
# Iteration 84 completed in 96s
# Start of iteration 85
# Current loss value: 4317228000.0
# Iteration 85 completed in 112s
# Start of iteration 86
# Current loss value: 4317228000.0
# Iteration 86 completed in 96s
# Start of iteration 87
# Current loss value: 4317228000.0
# Iteration 87 completed in 75s
# Start of iteration 88
# Current loss value: 4317228000.0
# Iteration 88 completed in 81s
# Start of iteration 89
# Current loss value: 4317228000.0
# Iteration 89 completed in 91s
# Start of iteration 90
# Current loss value: 4317228000.0
# Iteration 90 completed in 90s
# Start of iteration 91
# Current loss value: 4317228000.0
# Iteration 91 completed in 75s
# Start of iteration 92
# Current loss value: 4317228000.0
# Iteration 92 completed in 69s
# Start of iteration 93
# Current loss value: 4317228000.0
# Iteration 93 completed in 69s
# Start of iteration 94
# Current loss value: 4317228000.0
# Iteration 94 completed in 75s
# Start of iteration 95
# Current loss value: 4317228000.0
# Iteration 95 completed in 75s
# Start of iteration 96
# Current loss value: 4317228000.0
# Iteration 96 completed in 91s
# Start of iteration 97
# Current loss value: 4317228000.0
# Iteration 97 completed in 69s
# Start of iteration 98
# Current loss value: 4317228000.0
# Iteration 98 completed in 69s
# Start of iteration 99
# Current loss value: 4317228000.0
# Iteration 99 completed in 69s
# Start of iteration 100
# Current loss value: 4317228000.0
# Iteration 100 completed in 75s
# Start of iteration 101
# Current loss value: 4317228000.0
# Iteration 101 completed in 91s
# Start of iteration 102
# Current loss value: 4317228000.0
# Iteration 102 completed in 80s
# Start of iteration 103
# Current loss value: 4317228000.0
# Iteration 103 completed in 91s
# Start of iteration 104
# Current loss value: 4317228000.0
# Iteration 104 completed in 90s
# Start of iteration 105
# Current loss value: 4317228000.0
# Iteration 105 completed in 91s
# Start of iteration 106
# Current loss value: 4317228000.0
# Iteration 106 completed in 91s
# Start of iteration 107
# Current loss value: 4317228000.0
# Iteration 107 completed in 69s
# Start of iteration 108
# Current loss value: 4317228000.0
# Iteration 108 completed in 85s
# Start of iteration 109
# Current loss value: 4317228000.0
# Iteration 109 completed in 107s
# Start of iteration 110
# Current loss value: 4317228000.0
# Iteration 110 completed in 80s
# Start of iteration 111
# Current loss value: 4317228000.0
# Iteration 111 completed in 86s
# Start of iteration 112
# Current loss value: 4317228000.0
# Iteration 112 completed in 69s
# Start of iteration 113
# Current loss value: 4317228000.0
# Iteration 113 completed in 75s
# Start of iteration 114
# Current loss value: 4317228000.0
# Iteration 114 completed in 91s
# Start of iteration 115
# Current loss value: 4317228000.0
# Iteration 115 completed in 85s
# Start of iteration 116
# Current loss value: 4317228000.0
# Iteration 116 completed in 91s
# Start of iteration 117
# Current loss value: 4317228000.0
# Iteration 117 completed in 75s
# Start of iteration 118
# Current loss value: 4317228000.0
# Iteration 118 completed in 69s
# Start of iteration 119
# Current loss value: 4317228000.0
# Iteration 119 completed in 91s
# Start of iteration 120
# Current loss value: 4317228000.0
# Iteration 120 completed in 91s
# Start of iteration 121
# Current loss value: 4317228000.0
# Iteration 121 completed in 91s
# Start of iteration 122
# Current loss value: 4317228000.0
# Iteration 122 completed in 74s
# Start of iteration 123
# Current loss value: 4317228000.0
# Iteration 123 completed in 85s
# Start of iteration 124
# Current loss value: 4317228000.0
# Iteration 124 completed in 91s
# Start of iteration 125
# Current loss value: 4317228000.0
# Iteration 125 completed in 75s
# Start of iteration 126
# Current loss value: 4317228000.0
# Iteration 126 completed in 75s
# Start of iteration 127
# Current loss value: 4317228000.0
# Iteration 127 completed in 91s
# Start of iteration 128
# Current loss value: 4317228000.0
# Iteration 128 completed in 69s
# Start of iteration 129
# Current loss value: 4317228000.0
# Iteration 129 completed in 80s
# Start of iteration 130
# Current loss value: 4317228000.0
# Iteration 130 completed in 91s
# Start of iteration 131
# Current loss value: 4317228000.0
# Iteration 131 completed in 80s
# Start of iteration 132
# Current loss value: 4317228000.0
# Iteration 132 completed in 96s
# Start of iteration 133
# Current loss value: 4317228000.0
# Iteration 133 completed in 91s
# Start of iteration 134
# Current loss value: 4317228000.0
# Iteration 134 completed in 69s
# Start of iteration 135
# Current loss value: 4317228000.0
# Iteration 135 completed in 75s
# Start of iteration 136
# Current loss value: 4317228000.0
# Iteration 136 completed in 91s
# Start of iteration 137
# Current loss value: 4317228000.0
# Iteration 137 completed in 90s
# Start of iteration 138
# Current loss value: 4317228000.0
# Iteration 138 completed in 90s
# Start of iteration 139
# Current loss value: 4317228000.0
# Iteration 139 completed in 69s
# Start of iteration 140
# Current loss value: 4317228000.0
# Iteration 140 completed in 69s
# Start of iteration 141
# Current loss value: 4317228000.0
# Iteration 141 completed in 91s
# Start of iteration 142
# Current loss value: 4317228000.0
# Iteration 142 completed in 69s
# Start of iteration 143
# Current loss value: 4317228000.0
# Iteration 143 completed in 91s
# Start of iteration 144
# Current loss value: 4317228000.0
# Iteration 144 completed in 80s
# Start of iteration 145
# Current loss value: 4317228000.0
# Iteration 145 completed in 69s
# Start of iteration 146
# Current loss value: 4317228000.0
# Iteration 146 completed in 91s
# Start of iteration 147
# Current loss value: 4317228000.0
# Iteration 147 completed in 90s
# Start of iteration 148
# Current loss value: 4317228000.0
# Iteration 148 completed in 69s
# Start of iteration 149
# Current loss value: 4317228000.0
# Iteration 149 completed in 91s
# Start of iteration 150
# Current loss value: 4317228000.0
# Iteration 150 completed in 90s
# Start of iteration 151
# Current loss value: 4317228000.0
# Iteration 151 completed in 69s
# Start of iteration 152
# Current loss value: 4317228000.0
# Iteration 152 completed in 91s
# Start of iteration 153
# Current loss value: 4317228000.0
# Iteration 153 completed in 69s
# Start of iteration 154
# Current loss value: 4317228000.0
# Iteration 154 completed in 80s
# Start of iteration 155
# Current loss value: 4317228000.0
# Iteration 155 completed in 69s
# Start of iteration 156
# Current loss value: 4317228000.0
# Iteration 156 completed in 69s
# Start of iteration 157
# Current loss value: 4317228000.0
# Iteration 157 completed in 91s
# Start of iteration 158
# Current loss value: 4317228000.0
# Iteration 158 completed in 107s
# Start of iteration 159
# Current loss value: 4317228000.0
# Iteration 159 completed in 86s
# Start of iteration 160
# Current loss value: 4317228000.0
# Iteration 160 completed in 93s
# Start of iteration 161
# Current loss value: 4317228000.0
# Iteration 161 completed in 86s
# Start of iteration 162
# Current loss value: 4317228000.0
# Iteration 162 completed in 93s
# Start of iteration 163
# Current loss value: 4317228000.0
# Iteration 163 completed in 95s
# Start of iteration 164
# Current loss value: 4317228000.0
# Iteration 164 completed in 100s
# Start of iteration 165
# Current loss value: 4317228000.0
# Iteration 165 completed in 93s
# Start of iteration 166
# Current loss value: 4317228000.0
# Iteration 166 completed in 86s
# Start of iteration 167
# Current loss value: 4317228000.0
# Iteration 167 completed in 99s
# Start of iteration 168
# Current loss value: 4317228000.0
# Iteration 168 completed in 113s
# Start of iteration 169
# Current loss value: 4317228000.0
# Iteration 169 completed in 86s
# Start of iteration 170
# Current loss value: 4317228000.0
# Iteration 170 completed in 93s
# Start of iteration 171
# Current loss value: 4317228000.0
# Iteration 171 completed in 87s
# Start of iteration 172
# Current loss value: 4317228000.0
# Iteration 172 completed in 92s
# Start of iteration 173
# Current loss value: 4317228000.0
# Iteration 173 completed in 90s
# Start of iteration 174
# Current loss value: 4317228000.0
# Iteration 174 completed in 69s
# Start of iteration 175
# Current loss value: 4317228000.0
# Iteration 175 completed in 91s
# Start of iteration 176
# Current loss value: 4317228000.0
# Iteration 176 completed in 74s
# Start of iteration 177
# Current loss value: 4317228000.0
# Iteration 177 completed in 112s
# Start of iteration 178
# Current loss value: 4317228000.0
# Iteration 178 completed in 133s
# Start of iteration 179
# Current loss value: 4317228000.0
# Iteration 179 completed in 106s
# Start of iteration 180
# Current loss value: 4317228000.0
# Iteration 180 completed in 100s
# Start of iteration 181
# Current loss value: 4317228000.0
# Iteration 181 completed in 113s
# Start of iteration 182
# Current loss value: 4317228000.0
# Iteration 182 completed in 86s
# Start of iteration 183
# Current loss value: 4317228000.0
# Iteration 183 completed in 99s
# Start of iteration 184
# Current loss value: 4317228000.0
# Iteration 184 completed in 86s
# Start of iteration 185
# Current loss value: 4317228000.0
# Iteration 185 completed in 101s
# Start of iteration 186
# Current loss value: 4317228000.0
# Iteration 186 completed in 75s
# Start of iteration 187
# Current loss value: 4317228000.0
# Iteration 187 completed in 74s
# Start of iteration 188
# Current loss value: 4317228000.0
# Iteration 188 completed in 69s
# Start of iteration 189
# Current loss value: 4317228000.0
# Iteration 189 completed in 80s
# Start of iteration 190
# Current loss value: 4317228000.0
# Iteration 190 completed in 69s
# Start of iteration 191
# Current loss value: 4317228000.0
# Iteration 191 completed in 107s
# Start of iteration 192
# Current loss value: 4317228000.0
# Iteration 192 completed in 70s
# Start of iteration 193
# Current loss value: 4317228000.0
# Iteration 193 completed in 80s
# Start of iteration 194
# Current loss value: 4317228000.0
# Iteration 194 completed in 91s
# Start of iteration 195
# Current loss value: 4317228000.0
# Iteration 195 completed in 85s
# Start of iteration 196
# Current loss value: 4317228000.0
# Iteration 196 completed in 75s
# Start of iteration 197
# Current loss value: 4317228000.0
# Iteration 197 completed in 90s
# Start of iteration 198
# Current loss value: 4317228000.0
# Iteration 198 completed in 70s
# Start of iteration 199
# Current loss value: 4317228000.0
# Iteration 199 completed in 90s
# Start of iteration 200
# Current loss value: 4317228000.0
# Iteration 200 completed in 85s
# Start of iteration 201
# Current loss value: 4317228000.0
# Iteration 201 completed in 91s
# Start of iteration 202
# Current loss value: 4317228000.0
# Iteration 202 completed in 69s
# Start of iteration 203
# Current loss value: 4317228000.0
# Iteration 203 completed in 75s
# Start of iteration 204
# Current loss value: 4317228000.0
# Iteration 204 completed in 75s
# Start of iteration 205
# Current loss value: 4317228000.0
# Iteration 205 completed in 69s
# Start of iteration 206
# Current loss value: 4317228000.0
# Iteration 206 completed in 90s
# Start of iteration 207
# Current loss value: 4317228000.0
# Iteration 207 completed in 85s
# Start of iteration 208
# Current loss value: 4317228000.0
# Iteration 208 completed in 69s
# Start of iteration 209
# Current loss value: 4317228000.0
# Iteration 209 completed in 69s
# Start of iteration 210
# Current loss value: 4317228000.0
# Iteration 210 completed in 76s
# Start of iteration 211
# Current loss value: 4317228000.0
# Iteration 211 completed in 93s
# Start of iteration 212
# Current loss value: 4317228000.0
# Iteration 212 completed in 113s
# Start of iteration 213
# Current loss value: 4317228000.0
# Iteration 213 completed in 133s
# Start of iteration 214
# Current loss value: 4317228000.0
# Iteration 214 completed in 93s
# Start of iteration 215
# Current loss value: 4317228000.0
# Iteration 215 completed in 113s
# Start of iteration 216
# Current loss value: 4317228000.0
# Iteration 216 completed in 107s
# Start of iteration 217
# Current loss value: 4317228000.0
# Iteration 217 completed in 106s
# Start of iteration 218
# Current loss value: 4317228000.0
# Iteration 218 completed in 126s
# Start of iteration 219
# Current loss value: 4317228000.0
# Iteration 219 completed in 87s
# Start of iteration 220
# Current loss value: 4317228000.0
# Iteration 220 completed in 100s
# Start of iteration 221
# Current loss value: 4317228000.0
# Iteration 221 completed in 106s
# Start of iteration 222
# Current loss value: 4317228000.0
# Iteration 222 completed in 106s
# Start of iteration 223
# Current loss value: 4317228000.0
# Iteration 223 completed in 99s
# Start of iteration 224
# Current loss value: 4317228000.0
# Iteration 224 completed in 96s
# Start of iteration 225
# Current loss value: 4317228000.0
# Iteration 225 completed in 80s
# Start of iteration 226
# Current loss value: 4317228000.0
# Iteration 226 completed in 85s
# Start of iteration 227
# Current loss value: 4317228000.0
# Iteration 227 completed in 85s
# Start of iteration 228
# Current loss value: 4317228000.0
# Iteration 228 completed in 96s
# Start of iteration 229
# Current loss value: 4317228000.0
# Iteration 229 completed in 112s
# Start of iteration 230
# Current loss value: 4317228000.0
# Iteration 230 completed in 96s
# Start of iteration 231
# Current loss value: 4317228000.0
# Iteration 231 completed in 93s
# Start of iteration 232
# Current loss value: 4317228000.0
# Iteration 232 completed in 106s
# Start of iteration 233
# Current loss value: 4317228000.0
# Iteration 233 completed in 94s
# Start of iteration 234
# Current loss value: 4317228000.0
# Iteration 234 completed in 119s
# Start of iteration 235
# Current loss value: 4317228000.0
# Iteration 235 completed in 133s
# Start of iteration 236
# Current loss value: 4317228000.0
# Iteration 236 completed in 126s
# Start of iteration 237
# Current loss value: 4317228000.0
# Iteration 237 completed in 133s
# Start of iteration 238
# Current loss value: 4317228000.0
# Iteration 238 completed in 119s
# Start of iteration 239
# Current loss value: 4317228000.0
# Iteration 239 completed in 107s
# Start of iteration 240
# Current loss value: 4317228000.0
# Iteration 240 completed in 107s
# Start of iteration 241
# Current loss value: 4317228000.0
# Iteration 241 completed in 101s
# Start of iteration 242
# Current loss value: 4317228000.0
# Iteration 242 completed in 101s
# Start of iteration 243
# Current loss value: 4317228000.0
# Iteration 243 completed in 107s
# Start of iteration 244
# Current loss value: 4317228000.0
# Iteration 244 completed in 115s
# Start of iteration 245
# Current loss value: 4317228000.0
# Iteration 245 completed in 133s
# Start of iteration 246
# Current loss value: 4317228000.0
# Iteration 246 completed in 133s
# Start of iteration 247
# Current loss value: 4317228000.0
# Iteration 247 completed in 139s
# Start of iteration 248
# Current loss value: 4317228000.0
# Iteration 248 completed in 140s
# Start of iteration 249
# Current loss value: 4317228000.0
# Iteration 249 completed in 139s
# Start of iteration 250
# Current loss value: 4317228000.0
# Iteration 250 completed in 135s
# Start of iteration 251
# Current loss value: 4317228000.0
# Iteration 251 completed in 140s
# Start of iteration 252
# Current loss value: 4317228000.0
# Iteration 252 completed in 139s
# Start of iteration 253
# Current loss value: 4317228000.0
# Iteration 253 completed in 139s
# Start of iteration 254
# Current loss value: 4317228000.0
# Iteration 254 completed in 139s
# Start of iteration 255
# Current loss value: 4317228000.0
# Iteration 255 completed in 139s
# Start of iteration 256
# Current loss value: 4317228000.0
# Iteration 256 completed in 139s
# Start of iteration 257
# Current loss value: 4317228000.0
# Iteration 257 completed in 125s
# Start of iteration 258
# Current loss value: 4317228000.0
# Iteration 258 completed in 135s
# Start of iteration 259
# Current loss value: 4317228000.0
# Iteration 259 completed in 133s
# Start of iteration 260
# Current loss value: 4317228000.0
# Iteration 260 completed in 880s
# Start of iteration 261
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-54e0a090ebb0> in <module>()
#       7     start_time = time.time()
#       8     x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
# ----> 9                                      fprime=evaluator.grads, maxfun=20)
#      10     print('Current loss value:', min_val)
#      11     end_time = time.time()
#
# ~\Anaconda3\envs\python3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~\Anaconda3\envs\python3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~\Anaconda3\envs\python3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# ~\Anaconda3\envs\python3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# <ipython-input-36-fb00c812db81> in loss(self, x)
#      18     def loss(self, x):
#      19         assert self.loss_value is None
# ---> 20         loss_value, grad_values = eval_loss_and_grads(x)
#      21         self.loss_value = loss_value
#      22         self.grad_values = grad_values
#
# <ipython-input-36-fb00c812db81> in eval_loss_and_grads(x)
#       5 def eval_loss_and_grads(x):
#       6     x = x.reshape((1, height, width, 3))
# ----> 7     outs = f_outputs([x])
#       8     loss_value = outs[0]
#       9     grad_values = outs[1].flatten().astype('float64')
#
# ~\Anaconda3\envs\python3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~\Anaconda3\envs\python3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\python3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~\Anaconda3\envs\python3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\python3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\python3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# This took a while on my piddly laptop (that isn't GPU-accelerated), but here is the beautiful output from the last iteration! (Notice that we need to subject our output image to the inverse of the transformation we did to our input images before it makes sense.)

# %%
x = x.reshape((height, width, 3))
x = x[:, :, ::-1]
x[:, :, 0] += 103.939
x[:, :, 1] += 116.779
x[:, :, 2] += 123.68
x = np.clip(x, 0, 255).astype('uint8')

Image.fromarray(x)

# %% [markdown]
# ## Conclusion and further improvements
#
# It's now your turn to play! Try changing the input images, their sizes, the weights of the different loss functions, the features used to construct them and enjoy different sorts of output. If you end up creating something you truly wish to share, [please do so](https://twitter.com/copingbear)!
#
# As beautiful as the output of this code can be, the process we use to generate it is quite slow. And no matter how much you speed this algorithm up (with GPUs and creative hacks), it is still going to be a relatively expensive problem to solve. This is because we're solving an entire optimisation problem each time we want to generate an image.
#
# In an upcoming article (and corresponding iPython notebook), we're going to replace this the optimisation problem with an image transformation CNN, which in turn uses the VGG16 network as before to measure losses. When this transformation network is trained on many images given a fixed style image, we end up with a fully feed-forward CNN that we can apply for style transfer. This gives us a 1000x speed up over this implementation, making it suitable for a the *Stylist* webapp.
#
# But more on that later.
